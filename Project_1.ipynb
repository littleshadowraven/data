# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ вакансий на hh.ru

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
hh_data = pd.read_csv('dst-3.0_16_1_hh_database.csv',sep=';')
print(hh_data.shape)
# Out:
# (44744, 12)

# %% [markdown]
# 2. Выведите несколько первых (последних строк таблицы), чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
display(hh_data.head())
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений

# %%
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
hh_data.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
def applicant_education(education):
    education = ' '.join(education.split(' ')[:3]) #разделение строк по пробелам 
    if 'Высшее образование' in education:
        return 'высшее'
    elif 'Неоконченное высшее' in education:
       return 'неоконченное высшее'
    elif 'Среднее специальное' in education:
        return 'среднее специальное'
    elif 'Среднее образование' in education:
        return 'среднее'
   
hh_data['Образование'] = hh_data['Образование и ВУЗ'].apply(applicant_education)
print(hh_data['Образование'].unique()) #число уникальных значений признака Образование
print(len(hh_data[hh_data['Образование'] == 'среднее'])) #количество соискателей,которые имеют средний уровень образования
# Out:
# ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']
# 559

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол/возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
new_hh_data = hh_data['Пол, возраст'].str.split(',', expand=True) #разделяем один столбец на три
new_hh_data.columns=['Пол','Возраст','Дата рождения'] #присваиваем им названия
new_hh_data = new_hh_data.drop('Дата рождения',axis=1) #выкидываем столбец с датой рождения

new_hh_data['Пол'] = new_hh_data['Пол'].apply(lambda x: 'M' if 'Мужчина' in x else 'Ж') #преобразовываем признак 'Мужчина' в признак 'М'
new_hh_data['Возраст'] = new_hh_data['Возраст'].apply(lambda x: int(x.split(' ')[2])) #в возрасте отбрасываем все, кроме самого значения, и переводим в int
hh_data = pd.concat([hh_data,new_hh_data],axis=1) #объединяем две таблицы
hh_data = hh_data.drop('Пол, возраст', axis = 1) #выбрасываем ненужное

print(round(len(hh_data[hh_data['Пол'] == 'Ж'])/len(hh_data['Пол'])*100, 2)) #процент женских резюме
print(round(hh_data['Возраст'].mean(), 1)) #средний возраст соискателей
# Out:
# 19.07
# 32.2

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-третьих, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def get_experience(arg):
    if arg is np.nan:
        return None
    year_words=['год', 'года', 'лет'] #список ключевых слов по годам
    month_words=['месяц', 'месяца', 'месяцев'] #список ключевых слов по месяцам
    arg_list = arg.split(' ')[:7] #разделяем строку и оставляем только первые 7 значений списка (проверяем по .info())
    years = 0
    months = 0
    for i, word in enumerate(arg_list):  #ищем по ключевым словам, нужное значение находится под индексом i-1
        if word in year_words:
            years = int(arg_list[i-1])
        if word in month_words:
            months = int(arg_list[i-1])
    return int(years*12 + months)
hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы'].apply(get_experience) 
hh_data = hh_data.drop('Опыт работы', axis=1) #удаляем лишний столбец
print(round(hh_data['Опыт работы (месяц)'].median())) #медианный опыт работы
# Out:
# 100

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов миллионников:
#
#    <code> million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#
#
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
def get_city(arg):
    million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 
                      'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 
                      'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ]
    arg_city = list(arg.split(',')) #методом strip() отбросила запятую после названия города
    if arg_city[0].strip() == 'Москва' or arg_city[0].strip() == 'Санкт-Петербург':
        return arg_city[0].strip()
    elif arg_city[0].strip() in million_cities:
        return 'город миллионник'
    else:
        return 'другие'
hh_data['Город'] = hh_data['Город, переезд, командировки'].agg(get_city)

def get_ready_for_movement(arg):
    arg_list = arg.split(',')
    if ' не готов к переезду ' in arg_list or ' не готова к переезду ' in arg_list:
        return False
    else:
        return True
hh_data['Готовность к переезду'] = hh_data['Город, переезд, командировки'].apply(get_ready_for_movement) 
  
def get_ready_for_bisiness_trips(arg):
    arg_list = arg.split(',')
    if ' не готов к командировкам' in arg_list or ' не готова к командировкам' in arg_list:
        return False
    else: 
        return True
hh_data['Готовность к командировкам'] = hh_data['Город, переезд, командировки'].apply(get_ready_for_bisiness_trips)

hh_data = hh_data.drop('Город, переезд, командировки', axis = 1) #выбрасываем ненужное

print(round(len(hh_data[hh_data['Город'] == 'Санкт-Петербург'])/len(hh_data['Город'])*100)) #проценты соискателей живущих в Санкт-Петербурге


df = hh_data.loc[(hh_data['Готовность к переезду'] == True) & (hh_data['Готовность к командировкам'] == True)] #DataFrame с выполнением двух условий
print(round(len(df.index)/len(hh_data.index)*100)) #процент соискателей готовых одновременно и к переездам, и к командировкам
# Out:
# 11
# 32

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#Задание я поняла так, я погуглила метод One Hot Encoding, по первой же ссылке выдает метод get_dummies, его я и применила, 
# просто разбиение столбца 'Занятость' задала по ', ', вот ссылка https://stackoverflow.com/questions/50523537/one-hot-encoding-with-multiple-tags-in-the-column
df1 = hh_data['Занятость'].str.get_dummies(', ') #используем метод get_dummies
hh_data = pd.concat([hh_data,df1],axis=1) #объединяем две таблицы
hh_data = hh_data.drop('Занятость', axis = 1) #выбрасываем ненужное

df2 = hh_data.loc[(hh_data['проектная работа'] == True) & (hh_data['волонтерство'] == True)] #DataFrame с выполнением двух условий
print(len(df2.index)) #количество людей, которые ищут проектную работу и волонтёрство

df3 = hh_data['График'].str.get_dummies(', ') #используем метод get_dummies
hh_data = pd.concat([hh_data,df3],axis=1) #объединяем две таблицы
hh_data = hh_data.drop('График', axis = 1) #выбрасываем ненужное

df4 = hh_data.loc[(hh_data['вахтовый метод'] == True) & (hh_data['гибкий график'] == True)] #DataFrame с выполнением двух условий
print(len(df4.index)) #количество людей, которые хотят работать вахтовым методом и с гибким графиком
# Out:
# 436
# 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
def get_salary(arg):   #с помощью этой функции приводим все значения ЗП к типу float
    salary = float(arg.split(' ')[0])
    return salary

def get_salary_currency(arg): #преобразуем наименования валюты из наших данных в наименования из файла с курсом
    dict = {
        'грн':'UAH','USD':'USD', 
        'EUR':'EUR','белруб':'BYN',
        'KGS':'KGS','сум':'UZS',
        'KZT':'KZT','AZN':'AZN'
    }
    curr = arg.split(' ')[1].replace('.', '') #отделяем наше наименование валюты
    if curr == 'руб':
        return 'RUB'
    else:
        return dict[curr] #Заменяем на значение из словаря

currency = pd.read_csv('ExchangeRates.csv') 
currency['date'] = pd.to_datetime(currency['date']).dt.date #преобразуем дату из файла с переводов валют в формат datatime
hh_data['Обновление резюме'] = pd.to_datetime(hh_data['Обновление резюме']).dt.date #тоже самое делаем с нашим файлом hh
hh_data['ЗП (tmp)'] = hh_data['ЗП'].apply(get_salary) #преобразуем исходный столбец, обрезая значения валют
hh_data['Курс (tmp)'] = hh_data['ЗП'].apply(get_salary_currency) #применяем функцию, чтобы заменить валюты на их обозначение из файла с курсом
merged = hh_data.merge(   #объединяем эти таблицы
    currency, 
    left_on = ['Курс (tmp)', 'Обновление резюме'],
    right_on = ['currency', 'date'],
    how = 'left'
)
merged['close'] = merged['close'].fillna(1)  #значение close для рубля заполнила единицей 1 (курс рубля самого к себе)
merged['proportion'] = merged['proportion'].fillna(1) #тоже самое делаем с proportion
hh_data['ЗП (руб)'] = merged['close']*merged['ЗП (tmp)']/merged['proportion'] #преобразуем другие валюты в рубли с использованием файла с курсом валют и заносим в ЗП (руб)
data = hh_data.drop(['ЗП', 'ЗП (tmp)', 'Курс (tmp)'], axis=1) #как обычно выкидываем ненужное
print(round(hh_data['ЗП (руб)'].median()/1000)) #медианная заработная плата соискателей в нашей таблице (в рублях), целое число тысяч
# Out:
# 59

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 10))
plt.subplots_adjust(hspace=.0)

histplot = sns.histplot(
    data=hh_data, 
    x='Возраст', 
    bins=30,
    ax=axes[0]    
)
histplot.set_title('Распределение соискателей по возрасту', fontsize=16)
histplot.set_xlabel('Возраст')
histplot.set_ylabel('Число соискателей')
histplot.grid()

boxplot = sns.boxplot(
    data=hh_data,
    x='Возраст',
    orient='h',
    width=0.9,
    color='green',
    ax=axes[1]    
)
boxplot.set_xlabel('Возраст')
boxplot.grid()

# %% [markdown]
# Исходя из графиков распределения соискателей по возрасту, можно сделать вывод, что мода распределения равна около 30 годам, минимальный возраст соискателя - 14 лет, с максимумом интреснее: на гистограмме после 60 лет число соискателей близко к 0, на коробчатой диаграмме 90% соскателей имеют возраст до 50 лет, все остальные данные считаются выбросами, действительно, данные с возрастом как минимум после 65 (пенсионный возраст мужчин) считаются сомнительными. Максимальный возраст соискателя 100 лет, это явный выброс, похоже, что человек просто ошибся, когда заполнял анкету. Исходя из коробчатой диаграммы, можно сделать вывод, что большинство соискателей имеют возраст примерно от 26 до 36 лет (примерно).
#
# Код с графиками я практически никак не комментировала, поскольку он очень простой.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 10))
plt.subplots_adjust(hspace=.0) 

histplot = sns.histplot(
    data=hh_data, 
    x='Опыт работы (месяц)', 
    bins=30,
    ax=axes[0]
)
histplot.set_title('Распределение соискателей по опыту работы', fontsize=16)
histplot.set_xlabel('Опыт работы в месяцах')
histplot.set_ylabel('Число соискателей')
histplot.grid()

boxplot = sns.boxplot(
    data=hh_data,
    x='Опыт работы (месяц)',
    orient='h',
    width=0.9,
    color='green',
    ax=axes[1]
)
boxplot.set_xlabel('Опыт работы в месяцах')
boxplot.grid()

# %% [markdown]
# Из графиков можно сделать вывод, что модой распределения является опыт работы около 80 месяцев. Передельные значениями по коробчатой диаграмме: от 0 месяцев до 300 месяцев, остальные данные коробчатая диаграмма посчитала за выбросы, если значение опыта работы около 600 месяцев (50 лет) хотя бы возможно на практике, то значение с опытом работы близким к 1200 месяцев (100 лет) вообще не является правдивым. Опыт работы большинства соискателей находится в диапазоне от 50 до 150 месяцев (примерно).

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 10))
plt.subplots_adjust(hspace=.0)
df = hh_data['ЗП (руб)']/1000000 #перевела в миллионы

histplot = sns.histplot(
    data=hh_data, 
    x=df,
    y='Возраст', 
    bins=30,
    ax=axes[0]
)
histplot.set_title('Распределение соискателей по ЗП в зависимости от возраста', fontsize=16)
histplot.set_xlabel('Заработная плата в миллионах рублей')
histplot.set_ylabel('Возраст')
histplot.grid()

boxplot = sns.boxplot(
    data=hh_data,
    x=df,
    orient='h',
    width=0.9,
    color='green',
    ax=axes[1]
)
boxplot.set_xlabel('Заработная плата в миллионах рублей')
boxplot.grid()

# %% [markdown]
# По диаграмме видно, есть несколько аномальных значений, одно особенно выделяется: с зарплатой в 24 с лишним миллиона, из-за этого значения диаграмму невозможно адекватно анализировать, также выделяется значение с желаемой зработной платой в примерно 7 миллионов, оно также сильно искажает диаграмму и данные в целом. Всего 5 соискателей, которые желают зарплату свыше 1 миллиона. Минимальная желаемая заработная плата близка к 0 по сравнению с 24 миллионами, Большинство соискателей хотят ЗП до 1 миллиона, для адекватного анализа данных, я бы отфильтровала данные от аномальных значений. (Точка с возрастом в 100 лет тоже является аномальной.)

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
df = hh_data.loc[(hh_data['ЗП (руб)'] < 1000000)] #отфильтрую ненужные значения
df1 = df.groupby(      #сгруппируем выборки 
    ['Образование'], 
    as_index=False
)['ЗП (руб)'].median()
fig = px.bar(
    data_frame=df1,
    x='ЗП (руб)',
    y='Образование',    
    barmode="group",
    orientation='h',
    title='Зависимость медианной желаемой зарплаты от уровня образования'
)
print(df['ЗП (руб)'].median()) #если сравнить медианные значения желаемой заработной платы без фильтрации с данными после фильтрации, 
print(hh_data['ЗП (руб)'].median()) #то значения не так сильно отличаются
fig.show()
# Out:
# 59000.0
# 59019.0

# %% [markdown]
# Исходя из графика можно сделать вывод о том, что наибольшую желаемую заработную плату имеют соискатели с высшим образованием, что очень понятно, хорошее высшее образование требует больших затрат времени и денег, если учиться на платной основе. Желаемая заработная плата для соискателей с средне специальным и средним образованием примерно одинаковая. А уровень медианного значения желаемой ЗП у соискателей с неоконченным высшим отличается от медианного значения для соискателей с высшим образованием на 10 тыс.руб.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
df = hh_data.loc[(hh_data['ЗП (руб)'] < 1000000)] #отфильтрую ненужные значения

fig = plt.figure(figsize=(20, 15)) #судя по заданию, лучше всего построить "диаграмму с усами"
boxplot = sns.boxplot(data=df, x='ЗП (руб)', y='Город')
boxplot.set_title('Boxplot для желаемой ЗП соискателя  в зависимости от города', fontsize=16)
boxplot.set_xlabel('Желаемая заработная плата')
boxplot.set_ylabel('Город')
# Out:
# Text(0, 0.5, 'Город')

# %% [markdown]
# Размах желаемой зарплаты в Москве самый большой, так же как и медианное значение ЗП, у Санкт-Петербурга существеннно меньше, он находится на втором месте, а вот в городах миллионниках и других городах и размах и медиана практически совпадают. на мой взгляд, это связанно с тем, что в выборку городов миллионников попали далеко не все крупные города, например, в этом списке я не заметила город Краснодар, во вторых есть небольшие города, близкие к Москве, в которых желаемая ЗП тоже достатоно высокая. Стоит обратить внимание на наибольший показатель желаемой заработной платы (~924 тысячи рублей), он зафиксирован в группе других городов.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
df = hh_data.groupby( #сгруппируем выборки из базы данных
    ['Готовность к командировкам', 'Готовность к переезду'], #нам нужны признаки "Готовность к переезду" и "Готовность к командировкам"
    as_index=False
)['ЗП (руб)'].median()
fig = px.bar(
    data_frame=df,
    x='ЗП (руб)',
    y='Готовность к переезду',    
    barmode="group",
    color='Готовность к командировкам',
    orientation='h',
    title='Зависимость медианной зарплаты от готовности к командировкам/переезду'
)
fig.show()

# %% [markdown]
# Из данного графика видно, что у соискателей, которые готовы и к переездам и к командировкам, зависимость медианной заработной платы выше, а у соискателей, которые не готовы к перездам и командировкам, наоборот ниже. Также можно отметить, что у соискателей, готовых к переезду, выше заработная плата, это может быть связано с тем, что большинство соискателей стремятся в большие города (особенно в Москву и Санкт-Петербург), где медианная заработная плата выше, чем в провинциальных городах. Значение желаемамой медианной заработной платы соискателей, готовых и к переезду, и к командировкам можно найти, если навести курсор на этот столбец (67 тыс. руб.).

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
table = pd.pivot_table(hh_data,
               index='Образование',
               values='ЗП (руб)',
               columns='Возраст',
               aggfunc = 'median') 

heatmap = sns.heatmap(data=table, cmap='YlGnBu')
heatmap.set_title('Тепловая карта зависимости медианной желаемой заработной платы от возраста и образования', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Тепловая карта зависимости медианной желаемой заработной платы от возраста и образования')

# %% [markdown]
# Исходя из тепловой карты видно, что наибольшую желаемую заработную плату (в рублях) имеют соискатели с высшим образованием. В принципе наблюдается тенденция, что чем выше образование, тем выше желаемая заработная плата. Интересно, что в признаке высшее образование в возрасте от 14 до 17 лет есть яркое пятно, выглядит так, будто человек решил пошутить. Наблюдаются также яркие пятна во всех признаках образования в возрасте после 50 лет, а в средне специальном от 65 до 68 (тоже очень странное значение, похоже на выброс). Всплеск желаемой заработной платы наблюдается у соискателей с неоконченным высшим образованием после 40 лет, а у соискателей с высшим образованием примерно от 38 до 42 лет, к этому возрасту у большинства соискателей большой опыт работы, поэтому и высокие требования к заработной плате. Таким образом, для категории высшего образования наблюдается самый быстрый карьерный рост (то есть интенсивность роста заработной платы наибольшая).

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
fig = plt.figure(figsize=(12, 6))
df = hh_data['Опыт работы (месяц)']/12 #переведем опыт работы из месяцев в года

scatterplot = sns.scatterplot(  #диаграмма рассеяния
    data=hh_data,
    x='Возраст',
    y=df,
    s=30,
    color = 'purple'   
)

plt.plot(list(range(100)), list(range(100)), 'b') #дополнительная прямая y=x

scatterplot.set_title('Зависимость опыта работы от возраста', fontsize=16)
scatterplot.set_xlabel('Возраст')
scatterplot.set_ylabel('Опыт работы')
plt.show()

# %% [markdown]
# Из графика зависимости опыта работы от возраста видно, что чем больше возраст, тем больше опыт работы (ну это очевидно). С помощью графика y=x можем установить аномальные данные, по крайней мере 6 точек можно считать выбросами, так как опыт работы не может быть больше или равен возрасту. Очень смущает точка с возрастом 100 лет и опытом работы близким к 0, ее я бы тоже не учитывала, похоже на то, что человек ошибся при заполнении анкеты.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 10))
plt.subplots_adjust(hspace=.0)

df = hh_data[(hh_data['ЗП (руб)'] < 1000000)]

histplot = sns.histplot(
    data=df, 
    x='ЗП (руб)',
    y='Возраст', 
    bins=30,
    ax=axes[0]
)
histplot.set_title('Распределение соискателей по ЗП в зависимости от возраста', fontsize=16)
histplot.set_ylabel('Возраст')
histplot.grid()

boxplot = sns.boxplot(
    data=df,
    x='ЗП (руб)',
    orient='h',
    width=0.9,
    color='green',
    ax=axes[1]
)
boxplot.set_xlabel('Заработная плата')
boxplot.grid()

# %% [markdown]
# Я переделала диаграмму 3: распределение признака желаемой **"ЗП (руб)"** в зависимости от возраста, оставивим только соискателей с желаемой ЗП до миллиона. Теперь эти диаграммы можно анализировать.
# Самая яркая точка находится в районе до 30 лет, это говорит о том, что это возраст большинства людей, которые ищут работу. Моожно сказать, что масимума желаемая ЗП достигает в как раз районе 30 лет, когда у соискателя уже есть некий опыт работы, поэтому он может рассчитывать на зарплату повыше, с увеличением возраста желаемая заработная плата падает, это может быть связано с выходом на пенсию, а также с тем, что соискателю тяжелее найти новую работу, поэтому он занижает свои требования.
# В среднем желаемая заработная плата находится до 200 тыс.руб, медианное значение составляет около 60 тыс.руб. У 75% соискателей желаемая ЗП находится в пределах до 100тыс.руб. (включительно).

# %%
table1 = pd.pivot_table(hh_data,
               index='Образование',
               values='ЗП (руб)',
               columns='Пол',
               aggfunc = 'median') 

heatmap = sns.heatmap(data=table1, cmap='YlGnBu')
heatmap.set_title('Тепловая карта зависимости медианной желаемой заработной платы от пола и образования', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Тепловая карта зависимости медианной желаемой заработной платы от пола и образования')

# %% [markdown]
# Из тепловой карты зависимости медианной желаемой заработной платы от пола и образования видно, что женщины в среднем при одинаковом уровне образования имею желаемую ЗП ниже, чем мужчины. Самую маленькую желаемую ЗП имеют соискатели женщины со средне специальным уровнем образования. Это может быть связано с тем, что женщины чаще работают на низкоквалифицированных работах с низкой заработной платой (санитарки, кондукторы и т.д.).

# %%
table2 = pd.pivot_table(hh_data,
               index='Пол',
               values='ЗП (руб)',
               columns='Опыт работы (месяц)',
               aggfunc = 'median') 

heatmap = sns.heatmap(data=table2, cmap='YlGnBu')
heatmap.set_title('Тепловая карта зависимости медианной желаемой заработной платы от пола и образования', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Тепловая карта зависимости медианной желаемой заработной платы от пола и образования')

# %% [markdown]
# Из этой диаграммы видно, что после 360 месяцев опыта работы, данных по женщинам практически нет, т.е. они менее склонны менять работу при большом стаже работы. У мужчин наибольшая заработная плата наблюдается где-то после 180 месяцев стажа (15 лет), а падает она после 260 месяцев стажа (около 22 лет). Есть также аномальные значения, для мужчин при самом большом значении опыта работы, заработная плата тоже аномально высокая, больше похоже на шутку или ошибку при анкетировании.

# %%
df = hh_data.groupby( #сгруппируем выборки из базы данных
    ['полная занятость', 'гибкий график'], 
    as_index=False
)['ЗП (руб)'].median()
fig = px.bar(
    data_frame=df,
    x='ЗП (руб)',
    y='полная занятость',    
    barmode="group",
    color='гибкий график',
    orientation='h',
    title='Зависимость медианной зарплаты от выбора соискателя полной занятости и гибкого графика'
)
fig.show()

# %% [markdown]
# Из диаграммы видно, что соискатели с полной занятостью и гибким графиком имеют большую медианную желаемую ЗП, в отличие от соискателей с неполной занятостью. Тем не менее, соискатели с гибким графиком и пополной занятостью имеют большую медианную желаемую ЗП.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
dupl_columns = list(hh_data.columns)
mask = hh_data.duplicated(subset=dupl_columns)
hh_duplicates = hh_data[mask]
print(f'Число найденных дубликатов: {hh_duplicates.shape[0]}') #нашла число дубликатов
data_dedupped = hh_data.drop_duplicates(subset=dupl_columns)
# Out:
# Число найденных дубликатов: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
cols_null_persent = hh_data.isnull().mean() * 100
cols_with_null = cols_null_persent[cols_null_persent>0].sort_values(ascending=False)
display(cols_with_null)
print(hh_data['Опыт работы (месяц)'].isnull().sum()) #число пропусков в столбце «Опыт работы (месяц)
# Out:
# Опыт работы (месяц)                0.375469
# Последняя/нынешняя должность       0.004470
# Последнее/нынешнее место работы    0.002235
# dtype: float64
# 168

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
hh_data['Последнее/нынешнее место работы'] = hh_data['Последнее/нынешнее место работы'].dropna(how='any', axis=0) #удаляем пропуски в строках
hh_data['Последняя/нынешняя должность'] = hh_data['Последняя/нынешняя должность'].dropna(how='any', axis=0)

values = {'Опыт работы (месяц)': hh_data['Опыт работы (месяц)'].median()}
#заполняем пропуски в соответствии с заявленным словарем
hh_data = hh_data.fillna(values)
print(round(hh_data['Опыт работы (месяц)'].mean(), 2)) #среднее значение в столбце «Опыт работы (месяц)» после заполнения пропусков
# Out:
# 114.36

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
outliers1 = hh_data[hh_data['ЗП (руб)'] > 1000000] #резюме, в которых указана заработная плата выше 1 млн. рублей
outliers2 = hh_data[hh_data['ЗП (руб)'] < 1000] #резюме, в которых указана заработная плата ниже 1 тыс.
print(outliers1.shape[0] + outliers2.shape[0]) #количество выбросов 
hh_data = hh_data.drop(outliers1.index, axis=0) #выбросили лишнее
hh_data = hh_data.drop(outliers2.index, axis=0)
# Out:
# 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
outliers3 = hh_data[hh_data['Опыт работы (месяц)']/12 > hh_data['Возраст']] #резюме, в которых опыт работы в годах превышал возраст соискателя
print(outliers3.shape[0]) #число выбросов
hh_data = hh_data.drop(outliers3.index, axis=0) #выбросили лишнее
# Out:
# 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**? В какую сторону **асимметрично логарифмическое распределение**? Найдите выбросы с помощью **метода z-отклонения** и удалите их из данных, используйте логарифмический масштаб, сделайте **послабление на 1 сигму (возьмите 4 сигмы)** в сторону, противоположную асимметрии.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#гистограмма исходного признака
histplot = sns.histplot(hh_data['Возраст'], bins=30, ax=axes[0])
histplot.set_title('Распределение возраста')

#гистограмма в логарифмическом масштабе
log_age= np.log(hh_data['Возраст'] + 1)
histplot = sns.histplot(log_age , bins=30, ax=axes[1])
histplot.set_title('Распределение возраста в логарифмическом масштабе')

def outliers_z_score_mod(data, feature, left=3, right=4, log_scale=False): #функция для метода z-отклонения
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

outliers, cleaned = outliers_z_score_mod(hh_data, 'Возраст', log_scale=True)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
hh_data = hh_data.drop(outliers.index) #выкидываем ненужное
# Out:
# Число выбросов по методу z-отклонения: 3
